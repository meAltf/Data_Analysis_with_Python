# %%
"""
- Python can be used on a server to create web applications.
- Python can be used alongside software to create workflows.
- Python can connect to database systems. It can also read and modify files.
- Python can be used to handle big data and perform complex mathematics.
- Python can be used for rapid prototyping, or for production-ready software development.
"""

# %%
#basic, data types
#int
a = 15000000
type(a)
# Out:
# int

# %%
#basic, data types
#decimal-float
b = 1.50000000
type(b)
# Out:
# float

# %%
#String-str
c = " I am a future one of the best Data scientist in the world"
type(c)
# Out:
# str

# %%
#boolean-bool
#True or False
d= True
type(d)
# Out:
# bool

# %%
e=False
type(e)
# Out:
# bool

# %%
x = str(3)    # x will be '3'
y = int(3)    # y will be 3
z = float(3)  # z will be 3.0
print(x)
print(y)
print(z)
# Out:
# 3
# 3
# 3.0

# %%
#list data type
x = ["apple", "banana", "cherry"]
print(x)
# Out:
# ['apple', 'banana', 'cherry']

# %%
#tuple data types
x = ("apple", "banana", "cherry")
print(x)
# Out:
# ('apple', 'banana', 'cherry')

# %%
#range data types
x = range(6)
print(x)
# Out:
# range(0, 6)

# %%
#dict data types
x = {"name" : "Alataf", "age" : 21}
print(x)
# Out:
# {'name': 'Alataf', 'age': 21}

# %%
#set data type
x = {"apple", "banana", "cherry"}
print(x)
# Out:
# {'apple', 'cherry', 'banana'}

# %%
x = memoryview(bytes(5))

#display x:
print(x)

#display the data type of x:
print(type(x))
# Out:
# ...
# <class 'memoryview'>

# %%
#Assignment
#Try working with List, Dict, Tuple and Set Data types in python

# %%
#Many values to Multiple Variables
x, y, z = "Orange", "Banana", "Cherry"
print(x)
print(y)
print(z)
# Out:
# Orange
# Banana
# Cherry

# %%
fruits = ["apple", "banana", "cherry"]
x, y, z = fruits
print(x)
print(y)
print(z)
# Out:
# apple
# banana
# cherry

# %%
#part-1
x = "Python"
y = "is"
z = "awesome"
print(x, y, z)
# Out:
# Python is awesome

# %%
#part-2
x = "Python"
y = "is"
z = "awesome"
print(x, y, z)
# Out:
# Python is awesome

# %%
#It will gives error- TypeError
x = 6
y = "Alataf"
print(x + y)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-17-1df6c3b1ce24> in <cell line: 4>()
#       2 x = 6
#       3 y = "Alataf"
# ----> 4 print(x + y)
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
#This won't gives you an error
x = 6
y = "Alataf"
print(x, y)
# Out:
# 6 Alataf

# %%
#Magic of Global function
def myfunc():
  global x
  x = "fantastic"

myfunc()

print("Python is " + x)
# Out:
# Python is fantastic

# %%
x = "awesome" #It will work as local vriable after the global cames into picture

def myfunc():
  global x
  x = "fantastic"

myfunc()

print("Python is " + x)
# Out:
# Python is fantastic

# %%
import random

print(random.randrange(1, 10))

##Ading more later
# Out:
# 7
