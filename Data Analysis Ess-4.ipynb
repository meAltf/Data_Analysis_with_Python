# %%
## Real-time data analysis of E-learning platform

# %%
## Refer to this link to create or generate dummy data of any type
##https://mockaroo.com/

# %%
import pandas as pd

# %%
df_web = pd.read_csv('/content/MOCK_DATA.csv')

# %%
df_web
# Out:
#                                              page_path  Views  USers  \
# 0    http://de.vu/id/justo/sit.js?vivamus=vel&torto...      3     58
# 1    http://narod.ru/nisi/venenatis/tristique/fusce...      7     87
# 2    https://hatena.ne.jp/felis/sed/lacus.json?hac=...     51     22
# 3    https://mtv.com/congue/vivamus/metus/arcu.png?...     64     82
# 4    https://phpbb.com/elementum/in/hac/habitasse/p...     96     50
# ..                                                 ...    ...    ...
# 995  http://newsvine.com/nullam/molestie/nibh/in.pn...     37     10
# 996  http://123-reg.co.uk/mi/in/porttitor/pede/just...     61     98
# 997  https://marriott.com/gravida/nisi/at/nibh/in.j...     74     76
# 998  https://dailymail.co.uk/turpis/adipiscing.jpg?...     38     26
# 999  http://opera.com/vivamus/metus/arcu/adipiscing...     20      8
#
#      Views_per_user  Average_engagement_time  Event_count
# 0                65                       19           88
# ...

# %%
df_web.head
# Out:
# <bound method NDFrame.head of                                              page_path  Views  USers  \
# 0    http://de.vu/id/justo/sit.js?vivamus=vel&torto...      3     58
# 1    http://narod.ru/nisi/venenatis/tristique/fusce...      7     87
# 2    https://hatena.ne.jp/felis/sed/lacus.json?hac=...     51     22
# 3    https://mtv.com/congue/vivamus/metus/arcu.png?...     64     82
# 4    https://phpbb.com/elementum/in/hac/habitasse/p...     96     50
# ..                                                 ...    ...    ...
# 995  http://newsvine.com/nullam/molestie/nibh/in.pn...     37     10
# 996  http://123-reg.co.uk/mi/in/porttitor/pede/just...     61     98
# 997  https://marriott.com/gravida/nisi/at/nibh/in.j...     74     76
# 998  https://dailymail.co.uk/turpis/adipiscing.jpg?...     38     26
# 999  http://opera.com/vivamus/metus/arcu/adipiscing...     20      8
#
#      Views_per_user  Average_engagement_time  Event_count
# ...

# %%
df_web.describe()
# Out:
#             Views        USers  Views_per_user  Average_engagement_time  \
# count  1000.00000  1000.000000     1000.000000              1000.000000
# mean     51.06000    49.952000       49.361000                51.723000
# std      29.16122    28.829999       28.512868                28.381681
# min       1.00000     1.000000        1.000000                 1.000000
# 25%      25.00000    25.000000       24.000000                28.000000
# 50%      51.00000    50.000000       50.000000                53.000000
# 75%      77.00000    74.000000       73.000000                76.000000
# max     100.00000   100.000000      100.000000               100.000000
#
#        Event_count
# count  1000.000000
# mean     52.955000
# std      28.299538
# min       1.000000
# 25%      30.000000
# 50%      53.000000
# 75%      76.250000
# max     100.000000

# %%
df_web['Views_per_user'].mean()
# Out:
# 49.361

# %%
df_web['USers'].mean()
# Out:
# 49.952

# %%
df_web['Views'].mean()
# Out:
# 51.06

# %%
df_web['Average_engagement_time'].mean()
# Out:
# 51.723

# %%
df_web['Event_count'].mean()
# Out:
# 52.955

# %%
df_web['Event_count'].mean() / df_web['Views'].mean()
# Out:
# 1.0371132001566783

# %%
df_web.nlargest(10,'Views')
# Out:
#                                              page_path  Views  USers  \
# 15   http://disqus.com/mauris/enim/leo/rhoncus.xml?...    100     73
# 46   https://skyrock.com/tincidunt/lacus/at/velit/v...    100     29
# 133  https://blogspot.com/id.html?pede=nisl&loborti...    100     44
# 152  https://ning.com/dictumst/etiam/faucibus/cursu...    100     22
# 439  https://china.com.cn/mauris/lacinia/sapien.htm...    100      3
# 573  https://tinyurl.com/massa.png?praesent=id&blan...    100     87
# 577  http://redcross.org/nulla/neque/libero/convall...    100     44
# 592  https://people.com.cn/turpis/integer/aliquet/m...    100     19
# 718  http://bloglines.com/nulla/dapibus/dolor/vel/e...    100     58
# 855  http://bbc.co.uk/hendrerit/at.xml?dui=dapibus&...    100     58
#
#      Views_per_user  Average_engagement_time  Event_count
# 15               51                       26           86
# 46               89                       60           66
# ...

# %%
df_web.nlargest(10,'USers')
# Out:
#                                              page_path  Views  USers  \
# 297  http://redcross.org/consectetuer/eget/rutrum/a...     61    100
# 307  https://fda.gov/mauris/morbi/non/lectus/aliqua...     40    100
# 330  https://state.gov/felis/eu/sapien/cursus/vesti...     42    100
# 352  http://oaic.gov.au/sit/amet/nulla/quisque/arcu...     62    100
# 370  http://geocities.com/luctus.xml?ipsum=etiam&pr...     12    100
# 390  https://businessweek.com/sem/fusce/consequat/n...     75    100
# 597  https://chicagotribune.com/luctus/rutrum/nulla...     25    100
# 614  http://nps.gov/augue/vestibulum/rutrum.aspx?ul...     19    100
# 679  http://sfgate.com/magna.aspx?odio=penatibus&el...     73    100
# 770  https://discovery.com/neque/vestibulum.jpg?pro...     99    100
#
#      Views_per_user  Average_engagement_time  Event_count
# 297              15                       52           93
# 307              38                       97           97
# ...

# %%
df_web.nlargest(10,'Views_per_user')
# Out:
#                                              page_path  Views  USers  \
# 8    https://simplemachines.org/curabitur/gravida.x...     93      4
# 49   http://mapquest.com/gravida/nisi/at/nibh/in/ha...     92     32
# 87   http://ifeng.com/velit/donec/diam.jpg?integer=...     52     86
# 119  https://rakuten.co.jp/a/ipsum/integer/a/nibh/i...     19     60
# 311  https://ycombinator.com/sapien/a/libero/nam.js...     67     98
# 407  https://imgur.com/pede/justo/eu/massa/donec.js...     96     11
# 517  https://webeden.co.uk/elit/ac/nulla/sed.js?vol...     39     62
# 580  https://vimeo.com/leo.jsp?tincidunt=nulla&null...     90     15
# 685  https://usa.gov/mus/vivamus.jsp?ligula=vestibu...     17      6
# 705  https://godaddy.com/ipsum/dolor/sit/amet/conse...     51     60
#
#      Views_per_user  Average_engagement_time  Event_count
# 8               100                        8           70
# 49              100                       96           28
# ...

# %%
df_web[df_web['USers']>50].nlargest(10,'Views_per_user')
# Out:
#                                              page_path  Views  USers  \
# 87   http://ifeng.com/velit/donec/diam.jpg?integer=...     52     86
# 119  https://rakuten.co.jp/a/ipsum/integer/a/nibh/i...     19     60
# 311  https://ycombinator.com/sapien/a/libero/nam.js...     67     98
# 517  https://webeden.co.uk/elit/ac/nulla/sed.js?vol...     39     62
# 705  https://godaddy.com/ipsum/dolor/sit/amet/conse...     51     60
# 718  http://bloglines.com/nulla/dapibus/dolor/vel/e...    100     58
# 719  http://theatlantic.com/tempor/turpis/nec.json?...     48     75
# 768  https://google.cn/rhoncus/aliquam/lacus/morbi/...     65     54
# 955  http://yahoo.co.jp/odio/odio/elementum/eu.html...     43     98
# 114  http://springer.com/praesent/blandit/nam/nulla...     97     61
#
#      Views_per_user  Average_engagement_time  Event_count
# 87              100                       54           34
# 119             100                       69           61
# ...

# %%
df_web[df_web['USers']>50].nlargest(10,'Views_per_user')
# Out:
#                                              page_path  Views  USers  \
# 16   https://intel.com/parturient/montes.png?orci=p...     97     73
# 200  http://zdnet.com/at/vulputate/vitae/nisl/aenea...     76      5
# 254  https://ox.ac.uk/sit/amet/eleifend.js?maecenas...     89     45
# 418  http://ehow.com/tellus/semper/interdum/mauris/...     16     95
# 428  https://ucoz.com/augue/vel/accumsan.js?sed=qua...     37     88
# 442  http://com.com/dictumst/etiam/faucibus.jpg?tel...     50      9
# 602  http://redcross.org/volutpat/convallis/morbi/o...     77     34
# 695  https://nyu.edu/lectus/suspendisse/potenti.jpg...      2     17
# 861  http://hugedomains.com/ante/vivamus/tortor.jpg...     38     19
# 935  http://census.gov/gravida/nisi/at/nibh/in/hac/...      1     40
#
#      Views_per_user  Average_engagement_time  Event_count
# 16               71                      100           87
# 200              92                      100           68
# ...

# %%
# wgich pages are highly engaging where the unique users will be more than 100

# %%
df_web[df_web['USers']>50].nlargest(10,'Average_engagement_time')
# Out:
#                                              page_path  Views  USers  \
# 16   https://intel.com/parturient/montes.png?orci=p...     97     73
# 418  http://ehow.com/tellus/semper/interdum/mauris/...     16     95
# 428  https://ucoz.com/augue/vel/accumsan.js?sed=qua...     37     88
# 128  http://amazon.de/in/hac/habitasse/platea.jpg?s...     47     96
# 234  http://yale.edu/quisque/erat/eros/viverra/eget...     75     61
# 316  https://people.com.cn/nisi/venenatis.xml?phase...     47     81
# 555  http://spotify.com/ultrices.jsp?morbi=est&a=co...     92     82
# 811  http://github.io/quis/turpis/eget/elit/sodales...     79     82
# 963  https://icio.us/donec/diam/neque/vestibulum/eg...     12     86
# 165  https://multiply.com/porta/volutpat/erat/quisq...     87     90
#
#      Views_per_user  Average_engagement_time  Event_count
# 16               71                      100           87
# 418              19                      100           28
# ...

# %%
#which are the pages with highest event count

# %%
df_web.nlargest(10,'Event_count')
# Out:
#                                              page_path  Views  USers  \
# 60   http://sciencedirect.com/mauris/laoreet.xml?id...      5     26
# 101  https://cbslocal.com/lectus/in/est/risus.aspx?...     92     37
# 247  https://facebook.com/dictumst/etiam/faucibus/c...     65     79
# 325  https://shutterfly.com/hac/habitasse/platea/di...     62     71
# 364  https://myspace.com/sit.js?eu=at&tincidunt=nun...      3     95
# 384  https://indiegogo.com/accumsan/felis/ut/at/dol...     17     87
# 422  https://msn.com/venenatis/lacinia/aenean/sit/a...     36     87
# 445  http://i2i.jp/molestie/nibh/in/lectus/pellente...     17     43
# 465  https://last.fm/nulla/nisl/nunc/nisl/duis/bibe...     74     99
# 487  http://amazon.de/dui/vel/sem/sed/sagittis/nam/...     91     85
#
#      Views_per_user  Average_engagement_time  Event_count
# 60               49                       71          100
# 101              91                       64          100
# ...

# %%
#df_page_avg_time_10

# %%
df_web[df_web['Average_engagement_time']>10]
# Out:
#                                              page_path  Views  USers  \
# 0    http://de.vu/id/justo/sit.js?vivamus=vel&torto...      3     58
# 1    http://narod.ru/nisi/venenatis/tristique/fusce...      7     87
# 3    https://mtv.com/congue/vivamus/metus/arcu.png?...     64     82
# 4    https://phpbb.com/elementum/in/hac/habitasse/p...     96     50
# 5    http://icio.us/pulvinar/sed/nisl.html?tortor=m...      8     66
# ..                                                 ...    ...    ...
# 994  http://tinypic.com/aliquam.json?varius=sceleri...     77     76
# 995  http://newsvine.com/nullam/molestie/nibh/in.pn...     37     10
# 996  http://123-reg.co.uk/mi/in/porttitor/pede/just...     61     98
# 997  https://marriott.com/gravida/nisi/at/nibh/in.j...     74     76
# 999  http://opera.com/vivamus/metus/arcu/adipiscing...     20      8
#
#      Views_per_user  Average_engagement_time  Event_count
# 0                65                       19           88
# ...

# %%
df_page_avg_time = df_web[df_web['Average_engagement_time']>10]

# %%
df_page_avg_time
# Out:
#                                              page_path  Views  USers  \
# 0    http://de.vu/id/justo/sit.js?vivamus=vel&torto...      3     58
# 1    http://narod.ru/nisi/venenatis/tristique/fusce...      7     87
# 3    https://mtv.com/congue/vivamus/metus/arcu.png?...     64     82
# 4    https://phpbb.com/elementum/in/hac/habitasse/p...     96     50
# 5    http://icio.us/pulvinar/sed/nisl.html?tortor=m...      8     66
# ..                                                 ...    ...    ...
# 994  http://tinypic.com/aliquam.json?varius=sceleri...     77     76
# 995  http://newsvine.com/nullam/molestie/nibh/in.pn...     37     10
# 996  http://123-reg.co.uk/mi/in/porttitor/pede/just...     61     98
# 997  https://marriott.com/gravida/nisi/at/nibh/in.j...     74     76
# 999  http://opera.com/vivamus/metus/arcu/adipiscing...     20      8
#
#      Views_per_user  Average_engagement_time  Event_count
# 0                65                       19           88
# ...

# %%
df_page_avg_time.describe()
# Out:
#             Views       USers  Views_per_user  Average_engagement_time  \
# count  908.000000  908.000000      908.000000               908.000000
# mean    50.884361   50.291850       49.156388                56.356828
# std     29.304899   28.812393       28.399143                25.546775
# min      1.000000    1.000000        1.000000                11.000000
# 25%     25.000000   26.000000       23.000000                34.000000
# 50%     51.000000   50.000000       50.000000                58.000000
# 75%     77.000000   75.000000       73.000000                77.000000
# max    100.000000  100.000000      100.000000               100.000000
#
#        Event_count
# count   908.000000
# mean     53.312775
# std      28.269439
# min       1.000000
# 25%      30.000000
# 50%      54.000000
# 75%      77.000000
# max     100.000000

# %%
df_page_avg_time_less_4 = df_web[df_web['Average_engagement_time']<4]

# %%
df_page_avg_time_less_4
# Out:
#                                              page_path  Views  USers  \
# 63   https://tinyurl.com/molestie/hendrerit/at/vulp...     87      8
# 140  http://linkedin.com/duis/at/velit.aspx?ultrice...     55     87
# 144  http://t.co/duis/consequat.jsp?a=et&libero=ult...     34      3
# 280  https://gizmodo.com/lobortis/convallis/tortor/...     43     25
# 329  http://vinaora.com/aliquam/augue/quam/sollicit...     12     46
# 353  http://guardian.co.uk/lacus/purus/aliquet/at.p...     16     49
# 370  http://geocities.com/luctus.xml?ipsum=etiam&pr...     12    100
# 371  https://vkontakte.ru/montes/nascetur.html?ante...     86     98
# 423  http://networkadvertising.org/dapibus/duis/at....     58     61
# 538  http://blinklist.com/eget/tincidunt/eget/tempu...     66     52
# 559  http://nbcnews.com/lacus.xml?massa=ultrices&te...     10     64
# 608  http://vistaprint.com/eu/interdum/eu/tincidunt...     31     39
# 663  http://soundcloud.com/varius/nulla/facilisi/cr...     95     46
# ...

# %%
df_page_avg_time_less_4.describe()
# Out:
#            Views       USers  Views_per_user  Average_engagement_time  \
# count  24.000000   24.000000       24.000000                24.000000
# mean   46.708333   50.000000       48.625000                 1.916667
# std    27.294655   30.166206       32.886911                 0.829702
# min     4.000000    3.000000        3.000000                 1.000000
# 25%    31.000000   25.750000       20.750000                 1.000000
# 50%    41.500000   50.500000       49.000000                 2.000000
# 75%    67.000000   65.000000       78.000000                 3.000000
# max    95.000000  100.000000      100.000000                 3.000000
#
#        Event_count
# count    24.000000
# mean     56.208333
# std      28.037210
# min      13.000000
# 25%      30.000000
# 50%      57.500000
# 75%      74.250000
# max      98.000000

# %%
df_page_avg_time_less_4.head()
# Out:
#                                              page_path  Views  USers  \
# 63   https://tinyurl.com/molestie/hendrerit/at/vulp...     87      8
# 140  http://linkedin.com/duis/at/velit.aspx?ultrice...     55     87
# 144  http://t.co/duis/consequat.jsp?a=et&libero=ult...     34      3
# 280  https://gizmodo.com/lobortis/convallis/tortor/...     43     25
# 329  http://vinaora.com/aliquam/augue/quam/sollicit...     12     46
#
#      Views_per_user  Average_engagement_time  Event_count
# 63               56                        3           72
# 140              54                        3           94
# 144              87                        1           51
# 280              11                        1           97
# 329              61                        1           54

# %%
df_page_avg_time_less_4.tail()
# Out:
#                                              page_path  Views  USers  \
# 914  https://irs.gov/aenean/fermentum/donec.html?or...     91     13
# 958  https://census.gov/et.png?proin=viverra&interd...     77     60
# 962  https://about.com/ultrices/posuere/cubilia/cur...     45     81
# 991  https://mtv.com/fermentum/justo/nec/condimentu...     70     48
# 998  https://dailymail.co.uk/turpis/adipiscing.jpg?...     38     26
#
#      Views_per_user  Average_engagement_time  Event_count
# 914              38                        2           98
# 958              96                        2           32
# 962              87                        2           54
# 991              98                        1           73
# 998              29                        1           13

# %%
df_page_avg_time_15 = df_web[df_web['Average_engagement_time']>15]

# %%
df_page_avg_time_15
# Out:
#                                              page_path  Views  USers  \
# 0    http://de.vu/id/justo/sit.js?vivamus=vel&torto...      3     58
# 1    http://narod.ru/nisi/venenatis/tristique/fusce...      7     87
# 3    https://mtv.com/congue/vivamus/metus/arcu.png?...     64     82
# 4    https://phpbb.com/elementum/in/hac/habitasse/p...     96     50
# 5    http://icio.us/pulvinar/sed/nisl.html?tortor=m...      8     66
# ..                                                 ...    ...    ...
# 994  http://tinypic.com/aliquam.json?varius=sceleri...     77     76
# 995  http://newsvine.com/nullam/molestie/nibh/in.pn...     37     10
# 996  http://123-reg.co.uk/mi/in/porttitor/pede/just...     61     98
# 997  https://marriott.com/gravida/nisi/at/nibh/in.j...     74     76
# 999  http://opera.com/vivamus/metus/arcu/adipiscing...     20      8
#
#      Views_per_user  Average_engagement_time  Event_count
# 0                65                       19           88
# ...

# %%
df_page_avg_time_15.describe()
# Out:
#             Views       USers  Views_per_user  Average_engagement_time  \
# count  861.000000  861.000000      861.000000               861.000000
# mean    50.811847   50.389082       49.465738                58.720093
# std     29.407670   28.962379       28.471900                24.086992
# min      1.000000    1.000000        1.000000                16.000000
# 25%     25.000000   25.000000       24.000000                37.000000
# 50%     51.000000   50.000000       50.000000                60.000000
# 75%     77.000000   75.000000       73.000000                79.000000
# max    100.000000  100.000000      100.000000               100.000000
#
#        Event_count
# count   861.000000
# mean     53.493612
# std      28.249619
# min       1.000000
# 25%      31.000000
# 50%      54.000000
# 75%      77.000000
# max     100.000000

# %%
#Sort the data

# %%
df_page_avg_time = df_web[df_web['Average_engagement_time']>10]

# %%
df_page_avg_time_15[df_page_avg_time_15['USers']>15].sort_values(by=("Average_engagement_time"))
# Out:
#                                              page_path  Views  USers  \
# 788  http://who.int/at/feugiat/non/pretium.aspx?nul...     84     79
# 620  https://techcrunch.com/erat.jsp?eget=pretium&t...     49     33
# 34   http://wikia.com/nullam.js?adipiscing=turpis&m...     62     41
# 763  http://cbslocal.com/sed/magna/at/nunc.js?nasce...      5     50
# 12   https://toplist.cz/suspendisse.js?felis=ut&sed...     20     26
# ..                                                 ...    ...    ...
# 602  http://redcross.org/volutpat/convallis/morbi/o...     77     34
# 695  https://nyu.edu/lectus/suspendisse/potenti.jpg...      2     17
# 428  https://ucoz.com/augue/vel/accumsan.js?sed=qua...     37     88
# 16   https://intel.com/parturient/montes.png?orci=p...     97     73
# 254  https://ox.ac.uk/sit/amet/eleifend.js?maecenas...     89     45
#
#      Views_per_user  Average_engagement_time  Event_count
# 788               4                       16           25
# ...

# %%
def categorize(Views):
  if Views>=1000:
    return "Platinum"
  elif Views>=500:
    return "Gold"
  elif Views>=100:
    return "Silver"
  else:
    return "MOYE MOYE!!!"

# %%
#Adding segment based upon the Views count.. using map

# %%
df_web['segment'] = df_web['Views'].map(categorize)

# %%
df_web

### Adding more such concepts later
# Out:
#                                              page_path  Views  USers  \
# 0    http://de.vu/id/justo/sit.js?vivamus=vel&torto...      3     58
# 1    http://narod.ru/nisi/venenatis/tristique/fusce...      7     87
# 2    https://hatena.ne.jp/felis/sed/lacus.json?hac=...     51     22
# 3    https://mtv.com/congue/vivamus/metus/arcu.png?...     64     82
# 4    https://phpbb.com/elementum/in/hac/habitasse/p...     96     50
# ..                                                 ...    ...    ...
# 995  http://newsvine.com/nullam/molestie/nibh/in.pn...     37     10
# 996  http://123-reg.co.uk/mi/in/porttitor/pede/just...     61     98
# 997  https://marriott.com/gravida/nisi/at/nibh/in.j...     74     76
# 998  https://dailymail.co.uk/turpis/adipiscing.jpg?...     38     26
# 999  http://opera.com/vivamus/metus/arcu/adipiscing...     20      8
#
#      Views_per_user  Average_engagement_time  Event_count       segment
# ...

# %%
df_web[df_web['segment'] == 'platinum']
# Out:
# Empty DataFrame
# Columns: [page_path, Views, USers, Views_per_user, Average_engagement_time, Event_count, segment]
# Index: []
