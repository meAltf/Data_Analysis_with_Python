# %%
## What is a Dictionary-
## - It is something, which store as key & value pair , like- Hashmap in DSA

# %%
list_1 = ['hi', 'hey', 'hello']

# %%
list_1
# Out:
# ['hi', 'hey', 'hello']

# %%
list_1[0]
# Out:
# 'hi'

# %%
list_1[2]
# Out:
# 'hello'

# %%
list_1[5]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-6-8b128074ff9b> in <cell line: 1>()
# ----> 1 list_1[5]
#
# IndexError: list index out of range

# %%
list_1[-1] # means last index value
# Out:
# 'hello'

# %%
aadhar_alataf = ["alataf", "21", "958547852092", "altf@hotmail.com"]

# %%
aadhar_alataf[3]
# Out:
# 'altf@hotmail.com'

# %%
adhar_alataf_dt = {'name' :'Alataf', 'age':21,'UIDAI':'985412563685','mail_id':"altf@hotmail.com"}

# %%
adhar_alataf_dt['UIDAI']
# Out:
# '985412563685'

# %%
adhar_alataf_dt['mail_id']
# Out:
# 'altf@hotmail.com'

# %% [markdown]
# ## Pandas Library
# ### Pandas library is used for Data manipulation, a huge database.
#
# ### Extensively used for cleaning and preparing data for analysis.
#
# ### Pandas integrating using matploitlb, seaborn for Data-visualization. and many more...
#
# #### Fake excel data generator

# %%
# !pip install pandas

# %%
import pandas as pd

# %%
data = {
    'Name': ['John', 'Jane', 'Bob'],
    'Age': [32, 28, 45],
    'City': ['New York', 'London', 'Sydney']
}

# %%
data
# Out:
# {'Name': ['John', 'Jane', 'Bob'],
#  'Age': [32, 28, 45],
#  'City': ['New York', 'London', 'Sydney']}

# %%
df = pd.DataFrame(data)

# %%
print(df)
# Out:
#    Name  Age      City
# 0  John   32  New York
# 1  Jane   28    London
# 2   Bob   45    Sydney

# %%
import numpy as np

# %%
# Add 100 more data , using bard.ai or chatGPT
for i in range(100):
    name = f'Person{i+1}'
    age = np.random.randint(18, 65)
    city = np.random.choice(['New York', 'London', 'Sydney'])
    df = df.append({'Name': name, 'Age': age, 'City': city}, ignore_index=True)

print(df)
# Out:
#           Name  Age      City
# 0         John   32  New York
# 1         Jane   28    London
# 2          Bob   45    Sydney
# 3      Person1   52    London
# 4      Person2   25  New York
# ..         ...  ...       ...
# 198   Person96   60    London
# 199   Person97   48    London
# 200   Person98   57    London
# 201   Person99   41    Sydney
# 202  Person100   55    London
#
# [203 rows x 3 columns]
# <ipython-input-27-e2e68199bec2>:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Name': name, 'Age': age, 'City': city}, ignore_index=True)
# <ipython-input-27-e2e68199bec2>:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'Name': name, 'Age': age, 'City': city}, ignore_index=True)
# ...

# %%
df_file=pd.read_csv('/content/generic-food.csv')

# %%
df_file.head()
# Out:
#         FOOD NAME                 SCIENTIFIC NAME             GROUP  \
# 0        Angelica                Angelica keiskei  Herbs and Spices
# 1   Savoy cabbage  Brassica oleracea var. sabauda        Vegetables
# 2   Silver linden                  Tilia argentea  Herbs and Spices
# 3            Kiwi             Actinidia chinensis            Fruits
# 4  Allium (Onion)                          Allium        Vegetables
#
#                  SUB GROUP
# 0                    Herbs
# 1                 Cabbages
# 2                    Herbs
# 3          Tropical fruits
# 4  Onion-family vegetables

# %%
print(df.head)
# Out:
# <bound method NDFrame.head of           Name  Age      City
# 0         John   32  New York
# 1         Jane   28    London
# 2          Bob   45    Sydney
# 3      Person1   52    London
# 4      Person2   25  New York
# ..         ...  ...       ...
# 198   Person96   60    London
# 199   Person97   48    London
# 200   Person98   57    London
# 201   Person99   41    Sydney
# 202  Person100   55    London
#
# [203 rows x 3 columns]>

# %%
df_file['FOOD NAME']
# Out:
# 0                                               Angelica
# 1                                          Savoy cabbage
# 2                                          Silver linden
# 3                                                   Kiwi
# 4                                         Allium (Onion)
#                              ...
# 902                                      Romaine lettuce
# 903    Cow milk, pasteurized, vitamin A + D added, 0%...
# 904    Cow milk, pasteurized, vitamin A + D added, 1%...
# 905    Cow milk, pasteurized, vitamin A + D added, 2%...
# 906    Cow milk, pasteurized, vitamin D added, 3.25% fat
# Name: FOOD NAME, Length: 907, dtype: object

# %% [markdown]
# print(df_file['GROUP'])

# %%
df_file['SCIENTIFIC NAME']
# Out:
# 0                       Angelica keiskei
# 1         Brassica oleracea var. sabauda
# 2                         Tilia argentea
# 3                    Actinidia chinensis
# 4                                 Allium
#                      ...
# 902    Lactuca sativa L. var. longifolia
# 903                                  NaN
# 904                                  NaN
# 905                                  NaN
# 906                                  NaN
# Name: SCIENTIFIC NAME, Length: 907, dtype: object

# %%
df_file['SUB GROUP']
# Out:
# 0                        Herbs
# 1                     Cabbages
# 2                        Herbs
# 3              Tropical fruits
# 4      Onion-family vegetables
#                 ...
# 902            Leaf vegetables
# 903          Unfermented milks
# 904          Unfermented milks
# 905          Unfermented milks
# 906          Unfermented milks
# Name: SUB GROUP, Length: 907, dtype: object

# %%
df_file[['FOOD NAME','SUB GROUP']]
# Out:
#                                              FOOD NAME  \
# 0                                             Angelica
# 1                                        Savoy cabbage
# 2                                        Silver linden
# 3                                                 Kiwi
# 4                                       Allium (Onion)
# ..                                                 ...
# 902                                    Romaine lettuce
# 903  Cow milk, pasteurized, vitamin A + D added, 0%...
# 904  Cow milk, pasteurized, vitamin A + D added, 1%...
# 905  Cow milk, pasteurized, vitamin A + D added, 2%...
# 906  Cow milk, pasteurized, vitamin D added, 3.25% fat
#
#                    SUB GROUP
# 0                      Herbs
# 1                   Cabbages
# 2                      Herbs
# 3            Tropical fruits
# 4    Onion-family vegetables
# ..                       ...
# 902          Leaf vegetables
# 903        Unfermented milks
# 904        Unfermented milks
# ...

# %%
# Use filter or filter data using pandas
df_student_data = pd.read_csv('/content/Student_original.csv')

# %%
df_student_data.head()
# Out:
#   Student_ID gender NationalITy PlaceofBirth     StageID GradeID SectionID  \
# 0  STDN00001      M          KW       KuwaIT  lowerlevel    G-04         A
# 1  STDN00002      M          KW       KuwaIT  lowerlevel    G-04         A
# 2  STDN00003      M          KW       KuwaIT  lowerlevel    G-04         A
# 3  STDN00004      M          KW       KuwaIT  lowerlevel    G-04         A
# 4  STDN00005      M          KW       KuwaIT  lowerlevel    G-04         A
#
#   Topic Semester Relation  raisedhands  VisITedResources  AnnouncementsView  \
# 0    IT        F   Father           15                16                  2
# 1    IT        F   Father           20                20                  3
# 2    IT        F   Father           10                 7                  0
# 3    IT        F   Father           30                25                  5
# 4    IT        F   Father           40                50                 12
#
# ...

# %%
print(df_student_data[df_student_data['Student Marks'] >30])
# Out:
#     Student_ID gender NationalITy PlaceofBirth       StageID GradeID  \
# 0    STDN00001      M          KW       KuwaIT    lowerlevel    G-04
# 1    STDN00002      M          KW       KuwaIT    lowerlevel    G-04
# 2    STDN00003      M          KW       KuwaIT    lowerlevel    G-04
# 3    STDN00004      M          KW       KuwaIT    lowerlevel    G-04
# 4    STDN00005      M          KW       KuwaIT    lowerlevel    G-04
# ..         ...    ...         ...          ...           ...     ...
# 474  STDN00475      F      Jordan       Jordan  MiddleSchool    G-08
# 475  STDN00476      F      Jordan       Jordan  MiddleSchool    G-08
# 476  STDN00477      F      Jordan       Jordan  MiddleSchool    G-08
# 477  STDN00478      F      Jordan       Jordan  MiddleSchool    G-08
# 479  STDN00480      F      Jordan       Jordan  MiddleSchool    G-08
#
#     SectionID      Topic Semester Relation  raisedhands  VisITedResources  \
# ...

# %%
print(df_student_data[df_student_data['Student Marks'] >86])
# Out:
#     Student_ID gender NationalITy PlaceofBirth       StageID GradeID  \
# 14   STDN00015      F          KW       KuwaIT  MiddleSchool    G-08
# 53   STDN00054      F          KW       KuwaIT    HighSchool    G-11
# 62   STDN00063      M    venzuela     venzuela    HighSchool    G-10
# 68   STDN00069      F         USA          USA    HighSchool    G-12
# 79   STDN00080      F     lebanon      lebanon  MiddleSchool    G-07
# ..         ...    ...         ...          ...           ...     ...
# 457  STDN00458      F      Jordan       Jordan  MiddleSchool    G-08
# 459  STDN00460      M        Iraq         Iraq  MiddleSchool    G-08
# 465  STDN00466      F      Jordan       Jordan  MiddleSchool    G-08
# 466  STDN00467      F      Jordan       Jordan  MiddleSchool    G-08
# 467  STDN00468      F      Jordan       Jordan  MiddleSchool    G-08
#
#     SectionID      Topic Semester Relation  raisedhands  VisITedResources  \
# ...

# %%
avg_marks = df_student_data['Student Marks'].mean()

# %%
avg_marks
# Out:
# 67.7

# %%
df_student_data.tail()
# Out:
#     Student_ID gender NationalITy PlaceofBirth       StageID GradeID  \
# 475  STDN00476      F      Jordan       Jordan  MiddleSchool    G-08
# 476  STDN00477      F      Jordan       Jordan  MiddleSchool    G-08
# 477  STDN00478      F      Jordan       Jordan  MiddleSchool    G-08
# 478  STDN00479      F      Jordan       Jordan  MiddleSchool    G-08
# 479  STDN00480      F      Jordan       Jordan  MiddleSchool    G-08
#
#     SectionID      Topic Semester Relation  raisedhands  VisITedResources  \
# 475         A  Chemistry        S   Father            5                 4
# 476         A    Geology        F   Father           50                77
# 477         A    Geology        S   Father           55                74
# 478         A    History        F   Father           30                17
# 479         A    History        S   Father           35                14
#
#      AnnouncementsView  Discussion ParentAnsweringSurvey  \
# ...

# %%
df_student_data.describe()
# Out:
#        raisedhands  VisITedResources  AnnouncementsView  Discussion  \
# count   480.000000        480.000000         480.000000  480.000000
# mean     46.775000         54.797917          37.918750   43.283333
# std      30.779223         33.080007          26.611244   27.637735
# min       0.000000          0.000000           0.000000    1.000000
# 25%      15.750000         20.000000          14.000000   20.000000
# 50%      50.000000         65.000000          33.000000   39.000000
# 75%      75.000000         84.000000          58.000000   70.000000
# max     100.000000         99.000000          98.000000   99.000000
#
#        Student Marks
# count     480.000000
# mean       67.700000
# std        20.688302
# min        20.000000
# 25%        57.000000
# 50%        70.000000
# 75%        82.000000
# max       100.000000
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# ...
